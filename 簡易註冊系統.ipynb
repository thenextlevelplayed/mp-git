# %% [markdown]
# # 註冊系統

# %% [markdown]
# ## 註冊開始
# ## 是否結束(y/n):n
# ## 請輸入學生姓名:小王
# ## 是否結束(y/n):n
# ## 請輸入學生姓名:小李
# ## 是否結束(y/n):p
# ## 輸入錯誤請輸入y/n:y
# ## 註冊結束
# ## 班級共2人,名稱為小王 小李

# %%
print("註冊開始")
_name =[]
_number = 0 
sigh_up = True
while sigh_up != False:
    users= input("是否結束(y/n:)")
    if users == 'n':
        name= input('請輸入學生姓名:')
        _number = _number + 1
        _name.append(name) #_name.append(name) 為_name增加 name輸入的值  
    elif users != 'y' and 'n' :
        print('輸入錯誤，請輸入y/n:y')
    elif users == 'y':
        print('註冊結束')
        print('班級共{}人，名稱為{}'.format(_number, _name))
        sigh_up = False
# Out:
# 註冊開始
# 是否結束(y/n:)h
# 輸入錯誤，請輸入y/n:y
# 是否結束(y/n:)d
# 輸入錯誤，請輸入y/n:y
# 是否結束(y/n:)y
# 註冊結束
# 班級共0人，名稱為[]

# %% [markdown]
# # 隨機取 10個數字 用for 迴圈排序(不能用sort)

# %% [markdown]
# ## 由小到大

# %%
import numpy as np
a = np.random.randint(1,101, size=10)
print('初始陣列',a)
for i in range(len(a)+1):
    mini_index = i
    print('mini_index = ',mini_index)
    for j in range(i + 1,len(a)):
        print('第一個索引的值=',a[mini_index])
        print('跟第二個索引的值比較=',a[j])
        if (a[j] < a[mini_index]):            
            mini_index = j
            print('比較後取得目前最小的值的索引=',a[mini_index])
    if mini_index != i:
        a[mini_index], a[i] = a[i], a[mini_index]
        print('mini_index!=i')
        print('max_index=',max_index)
        print('i=',i)
        print('將預設的一開始是最小值的', a[max_index])
        print('取代排序後找到最小值',a[i])
print('排序後:',a)
# Out:
# 初始陣列 [ 7 40 30 31 10  2 10 71 81 27]
# mini_index =  0
# 第一個索引的值= 7
# 跟第二個索引的值比較= 40
# 第一個索引的值= 7
# 跟第二個索引的值比較= 30
# 第一個索引的值= 7
# 跟第二個索引的值比較= 31
# 第一個索引的值= 7
# 跟第二個索引的值比較= 10
# 第一個索引的值= 7
# 跟第二個索引的值比較= 2
# 比較後取得目前最小的值的索引= 2
# 第一個索引的值= 2
# 跟第二個索引的值比較= 10
# 第一個索引的值= 2
# 跟第二個索引的值比較= 71
# 第一個索引的值= 2
# 跟第二個索引的值比較= 81
# 第一個索引的值= 2
# 跟第二個索引的值比較= 27
# mini_index!=i
# max_index= 8
# i= 0
# 將預設的一開始是最小值的 81
# 取代排序後找到最小值 2
# mini_index =  1
# 第一個索引的值= 40
# 跟第二個索引的值比較= 30
# 比較後取得目前最小的值的索引= 30
# 第一個索引的值= 30
# 跟第二個索引的值比較= 31
# 第一個索引的值= 30
# 跟第二個索引的值比較= 10
# 比較後取得目前最小的值的索引= 10
# 第一個索引的值= 10
# 跟第二個索引的值比較= 7
# 比較後取得目前最小的值的索引= 7
# 第一個索引的值= 7
# 跟第二個索引的值比較= 10
# 第一個索引的值= 7
# 跟第二個索引的值比較= 71
# 第一個索引的值= 7
# 跟第二個索引的值比較= 81
# 第一個索引的值= 7
# 跟第二個索引的值比較= 27
# mini_index!=i
# max_index= 8
# i= 1
# 將預設的一開始是最小值的 81
# 取代排序後找到最小值 7
# mini_index =  2
# 第一個索引的值= 30
# 跟第二個索引的值比較= 31
# 第一個索引的值= 30
# 跟第二個索引的值比較= 10
# 比較後取得目前最小的值的索引= 10
# 第一個索引的值= 10
# 跟第二個索引的值比較= 40
# 第一個索引的值= 10
# 跟第二個索引的值比較= 10
# 第一個索引的值= 10
# ...

# %% [markdown]
# ## 由大到小

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
a = np.random.randint(1,101, size=10)
print('初始陣列',a)
for i in range(len(a)-1):
    max_index = i
    print('max_index = ',max_index)
    for j in range(i + 1,len(a)):
        print('第一個索引的值=',a[max_index])
        print('跟第二個索引的值比較=',a[j])
        if a[j] > a[max_index]:
            max_index = j
            print('目前最大的值=',a[max_index])
    if max_index != i:
        a[max_index], a[i] = a[i], a[max_index]
        print('當max_index!=i')
        print('max_index=',max_index)
        print('i=',i)
        print('將預設的一開始是最大值的', a[max_index])
        print('取代排序後找到最大值',a[i])
print('排序後:',a)
# Out:
# 初始陣列 [46 76 20 36 44 50 53 41 73 19]
# max_index =  0
# 第一個索引的值= 46
# 跟第二個索引的值比較= 76
# 目前最大的值= 76
# 第一個索引的值= 76
# 跟第二個索引的值比較= 20
# 第一個索引的值= 76
# 跟第二個索引的值比較= 36
# 第一個索引的值= 76
# 跟第二個索引的值比較= 44
# 第一個索引的值= 76
# 跟第二個索引的值比較= 50
# 第一個索引的值= 76
# 跟第二個索引的值比較= 53
# 第一個索引的值= 76
# 跟第二個索引的值比較= 41
# 第一個索引的值= 76
# 跟第二個索引的值比較= 73
# 第一個索引的值= 76
# 跟第二個索引的值比較= 19
# 當max_index!=i
# max_index= 1
# i= 0
# 將預設的一開始是最大值的 46
# 取代排序後找到最大值 76
# max_index =  1
# 第一個索引的值= 46
# 跟第二個索引的值比較= 20
# 第一個索引的值= 46
# 跟第二個索引的值比較= 36
# 第一個索引的值= 46
# 跟第二個索引的值比較= 44
# 第一個索引的值= 46
# 跟第二個索引的值比較= 50
# 目前最大的值= 50
# 第一個索引的值= 50
# 跟第二個索引的值比較= 53
# 目前最大的值= 53
# 第一個索引的值= 53
# 跟第二個索引的值比較= 41
# 第一個索引的值= 53
# 跟第二個索引的值比較= 73
# 目前最大的值= 73
# 第一個索引的值= 73
# 跟第二個索引的值比較= 19
# 當max_index!=i
# max_index= 8
# i= 1
# 將預設的一開始是最大值的 46
# 取代排序後找到最大值 73
# max_index =  2
# 第一個索引的值= 20
# 跟第二個索引的值比較= 36
# 目前最大的值= 36
# 第一個索引的值= 36
# 跟第二個索引的值比較= 44
# 目前最大的值= 44
# 第一個索引的值= 44
# 跟第二個索引的值比較= 50
# 目前最大的值= 50
# 第一個索引的值= 50
# 跟第二個索引的值比較= 53
# 目前最大的值= 53
# ...
